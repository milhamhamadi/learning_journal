# %% [markdown]
# Pandas Basic

# %% [markdown]
# Import Dataset from Local Disc

# %%
import pandas as pd

# %%
import numpy as np

# %%
#csv
#kalau ada di dalam folder yg sama
#pd.read_csv("Student_Marks.csv")

#kalau ada di dalam folder yang ada didalam folder .ipynb
pd.read_csv("pandas/Student_Marks.csv")

#kalau ada diluar folder dimana .ipynb terletak
#pd.read_csv("../week_2/Student_Marks.csv")
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
pd.read_csv("pandas/ref.csv", sep=';')
#sep bisa juga diganti delimiter
# Out:
#    ch1  ch2  ch3
# 0   10    1  100
# 1   20    2  200
# 2   30    3  300
# 3   40    4  400
# 4   50    5  500

# %%
df= pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %% [markdown]
# Data Overview

# %%
#untuk tau berapa rows dan column
#df.shape

#untuk tau berapa rows
#df.shape[0]

#untuk tau berapa column
#df.shape[1]
# Out:
# 23

# %%
#melihat data teratas (default 5)
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
#agar semua column ditamnpilkan
pd.set_option('display.max.columns', None)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
#melihat data 5 paling bawah
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe().T
#mendeteksi informasi dasar
#lihat adanya anomali atau tidak
#.T untuk tukar column ke rows agar lebih mudah dibaca
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# Data Exploration

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df['game_result'].unique()
#untuk melihat data uniq pada column tertentu
# Out:
# array(['L', 'W'], dtype=object)

# %%
df['game_result'].value_counts()
#menghitung data unique value di column
# Out:
# L    63157
# W    63157
# Name: game_result, dtype: int64

# %%
df['fran_id'].value_counts()

# %%
#mensortir data
#df.sort_values(by="pts", ascending = False)[['fran_id', 'pts']]

# %%
#ekstrak informasi berdasarkan unique values yg kita mau
df.loc[df['fran_id']=="Knicks",'opp_fran'].value_counts()
# Out:
# Celtics         526
# Sixers          471
# Pistons         382
# Hawks           368
# Warriors        335
# Wizards         323
# Lakers          310
# Kings           299
# Bulls           251
# Pacers          205
# Bucks           204
# Cavaliers       203
# Nets            189
# Rockets         145
# Heat            137
# Thunder         124
# Clippers        122
# Suns            120
# Trailblazers    105
# Magic            99
# Pelicans         90
# Jazz             90
# Spurs            90
# Raptors          85
# Nuggets          81
# Mavericks        68
# Baltimore        62
# Timberwolves     50
# Hornets          40
# Grizzlies        37
# Capitols         32
# Stags            23
# Bombers          23
# Olympians        20
# Steamrollers     20
# Rebels            9
# Falcons           6
# Ironmen           6
# Huskies           6
# Jets              5
# Packers           2
# Denver            2
# Redskins          2
# Waterloo          2
# Name: opp_fran, dtype: int64

# %%
#ekstrak values berdasarkan 2 unique values
df.loc[(df['year_id']==2010)&(df['fran_id']=='Knicks'), :]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 111053      55527  200910280MIA   NBA        1     2010  10/28/2009
# 111072      55537  200910300CHA   NBA        1     2010  10/30/2009
# 111103      55552  200910310NYK   NBA        0     2010  10/31/2009
# 111126      55564  200911020NYK   NBA        0     2010   11/2/2009
# 111160      55581  200911040NYK   NBA        0     2010   11/4/2009
# ...           ...           ...   ...      ...      ...         ...
# 113352      56677  201004070IND   NBA        1     2010    4/7/2010
# 113396      56699  201004090ORL   NBA        1     2010    4/9/2010
# 113428      56715  201004110NYK   NBA        0     2010   4/11/2010
# 113447      56724  201004120NYK   NBA        0     2010   4/12/2010
# 113486      56744  201004140TOR   NBA        1     2010   4/14/2010
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# ...

# %%
#slicing values
df.loc[df['team_id']=="TRH", 'year_id'].max()
# Out:
# 1947

# %%
#slicing values aggregate
df.loc[df['team_id']=="NYK", 'year_id'].agg(["min","max"])
#pake dua kurung diaggregate karena
# Out:
# min    1947
# max    2015
# Name: year_id, dtype: int64

# %%
#pengambilann data secara acak
df.sample(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 108265      54133  200804240UTA   NBA        0     2008   4/24/2008
# 39018       19510  197802070BUF   NBA        0     1978    2/7/1978
# 67495       33748  199201080MIL   NBA        1     1992    1/8/1992
# 34037       17019  197511130VIR   ABA        1     1976  11/13/1975
# 75708       37855  199504070POR   NBA        0     1995    4/7/1995
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 108265          85            1     UTA          Jazz   92  1698.5673
# 39018           47            0     BUF      Clippers  105  1395.9260
# 67495           35            0     UTA          Jazz   98  1610.9282
# 34037           10            0     SAA         Spurs  124  1547.6161
# 75708           73            0     POR  Trailblazers  127  1537.7054
#
#             elo_n  win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
#melihat total points all time
df.loc[df['fran_id']=="Warriors", ['seasongame','pts']].sum()
# Out:
# seasongame    237531
# pts           591224
# dtype: int64

# %%
#ekstrak info berdasarkan index
df.iloc[60:65]
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 60         31  194611170CLR   NBA        0     1947  11/17/1946           4
# 61         31  194611170CLR   NBA        1     1947  11/17/1946           8
# 62         32  194611180NYK   NBA        0     1947  11/18/1946           6
# 63         32  194611180NYK   NBA        1     1947  11/18/1946           7
# 64         33  194611180PIT   NBA        1     1947  11/18/1946           7
#
#     is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 60            0     CLR   Rebels   76  1314.2461  1307.6647  41.803886    CHS
# 61            0     CHS    Stags   78  1321.4366  1328.0181  43.933949    CLR
# 62            0     NYK   Knicks   61  1296.2185  1300.3541  41.037148    DTF
# 63            0     DTF  Falcons   57  1291.9098  1287.7742  39.717983    NYK
# 64            0     TRH  Huskies   48  1290.0051  1284.4910  39.374023    PIT
#
# ...

# %%
#ekstrak info berdasarkan column
df.loc[60:65, ['game_id', "year_id", '_iscopy', 'fran_id']].min()
# Out:
# game_id    194611170CLR
# year_id            1947
# _iscopy               0
# fran_id         Falcons
# dtype: object

# %% [markdown]
# Querry Data Set

# %%
df.sample(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 78281       39141  199604100CHH   NBA        0     1996  4/10/1996
# 41286       20644  197903090KCK   NBA        0     1979   3/9/1979
# 120795      60398  201304120POR   NBA        1     2013  4/12/2013
# 72680       36341  199402180ORL   NBA        0     1994  2/18/1994
# 68869       34435  199204260CHI   NBA        1     1992  4/26/1992
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# 78281           77            0     CHH  Pelicans   95  1499.6807  1477.8672
# 41286           68            0     KCK     Kings  121  1572.5726  1578.5927
# 120795          80            0     OKC   Thunder  106  1729.4036  1735.1042
# 72680           49            0     ORL     Magic  124  1564.5482  1586.1309
# 68869           84            1     MIA      Heat   90  1431.4713  1429.0767
#
#         win_equiv opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
#ekstrak values based on multiple conditions
df[
    (df['year_id']==2001) &
    (df['fran_id']=="Celtics") &
    (df['game_location']=="H") &
    (df['game_result']=="W")
][["opp_fran", "opp_pts"]] #untuk ngeprint apa aja yg mau diliat

# %%
df.query("year_id == 2001 & \
    fran_id == 'Celtics' & \
    game_location == 'H' & \
    game_result == 'W'"
    )[["opp_fran", "opp_pts"]]

# %% [markdown]
# Grouping and Aggregating

# %%
df.sample(5)

# %%
gr_1= df.groupby('game_result')
gr_1

# %%
gr_1.get_group('L')
#sudah tergroup based on unique value

# %%
df.groupby('game_result')['pts'].mean()
#grouping                 #aggregasi
# Out:
# game_result
# L     97.349209
# W    108.110756
# Name: pts, dtype: float64

# %% [markdown]
# Kombinasi GroupBy dan querry dan aggregation

# %%
df[
    (df['year_id']> 2010) &
    (df['fran_id']=="Spurs")
].groupby(['year_id','game_result'])['game_id'].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
df[
    (df['year_id']> 2010) &
    (df['fran_id']=="Spurs")
].groupby(['year_id','game_result']).agg({'pts' : 'mean','game_id' :'count'})
# Out:
#                             pts  game_id
# year_id game_result
# 2011    L             93.840000       25
#         W            106.698413       63
# 2012    L             94.350000       20
#         W            106.366667       60
# 2013    L             93.333333       30
#         W            106.232877       73
# 2014    L             96.925926       27
#         W            108.564103       78
# 2015    L             97.548387       31
#         W            106.224138       58

# %% [markdown]
# ## Manipulating Columns
#
# -create new column based on existing data
# -rename columns
# -drop columns

# %%
df.sample(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 36645       18323  197612190NYN   NBA        1     1977  12/19/1976
# 76905       38453  199601020ATL   NBA        0     1996    1/2/1996
# 119638      59820  201301210GSW   NBA        1     2013   1/21/2013
# 96084       48043  200312200CHI   NBA        0     2004  12/20/2003
# 611           306  194703200GSW   NBA        0     1947   3/20/1947
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# 36645           28            0     BOS   Celtics   94  1523.3386  1533.6521
# 76905           29            0     ATL     Hawks   88  1465.6803  1452.8132
# 119638          42            0     LAC  Clippers   99  1690.4485  1680.1566
# 96084           25            0     CHI     Bulls   87  1383.3918  1369.3823
# 611             57            0     PHW  Warriors   77  1360.3250  1361.7554
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
nba=df.copy()
#agar tidak merubah data asal

# %%
#create new column based on existing
nba['selisih_poin'] = nba['pts'] - nba['opp_pts']

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
#rename column
nba.rename(columns={'game_location': 'location', 'game_result' : 'result'})
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
nba.head()
#belum ada perubahan di nama column karena belum di save dan sebelum ini hanya preview
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
#inplace untuk save
nba.rename(columns={'game_location': 'location', 'game_result' : 'result'}, inplace=True)

# %%
nba.head(5)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
#drop columns
#untuk buang columns
nba.drop(['elo_i', 'elo_n'], axis=1, inplace=True)

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n location result  forecast notes  selisih_poin
# ...
